# %%
# Snowpark for Python
from snowflake.snowpark import Session
from snowflake.snowpark.version import VERSION
from snowflake.snowpark.functions import udf
import snowflake.snowpark.functions as F

# Snowpark ML
from snowflake.ml.modeling.xgboost import XGBRegressor
from snowflake.ml.modeling.model_selection import GridSearchCV
from snowflake.ml.registry import Registry
from snowflake.ml._internal.utils import identifier
import snowflake.ml.modeling.preprocessing as snowml

import pandas as pd

# %%
connection_parameters = {
    "account": "ug94937.us-east4.gcp",
    "user": "ADITYASINGH",
    "password": os.environ.get('SF_Password'),
    "role": "ADITYASINGH",  # optional
    "warehouse": "FOSFOR_INSIGHT_WH",  # optional
#     "authenticator": "externalbrowser", # optional
    "database": "FIRST_DB",  # optional
    "schema": "PUBLIC",  # optional
}

# %%
# Make a Snowpark Connection

################################################################################################################
#  You can also use the SnowSQL Client to configure your connection params:
#  https://docs.snowflake.com/en/user-guide/snowsql-install-config.html
#
#  >>> from snowflake.ml.utils import connection_params
#  >>> session = Session.builder.configs(connection_params.SnowflakeLoginOptions()
#  >>> ).create()   
#
#  NOTE: If you have named connection params then specify the connection name
#  Example:
#  
#  >>> session = Session.builder.configs(
#  >>> connection_params.SnowflakeLoginOptions(connection_name='connections.snowml')
#  >>> ).create()
#
#################################################################################################################

# Edit the connection.json before creating the session object below
# Create Snowflake Session object
# connection_parameters = json.load(open('connection.json'))
session = Session.builder.configs(connection_parameters).create()
session.sql_simplifier_enabled = True

snowflake_environment = session.sql('SELECT current_user(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('\nConnection Established with the following parameters:')
print('User                        : {}'.format(snowflake_environment[0][0]))
print('Role                        : {}'.format(session.get_current_role()))
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Snowflake version           : {}'.format(snowflake_environment[0][1]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Connection Established with the following parameters:
# User                        : ADITYASINGH
# Role                        : "ADITYASINGH"
# Database                    : "FIRST_DB"
# Schema                      : "PUBLIC"
# Warehouse                   : "FOSFOR_INSIGHT_WH"
# Snowflake version           : 8.20.10
# Snowpark for Python version : 1.17.0

# %%
data = pd.read_csv('/data/diamonds.csv')
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data=data.drop("Unnamed: 0" , axis =1)
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#moving data to snowflake df
diamonds_df = session.create_dataframe(data)
diamonds_df.show()
# Out:
# ------------------------------------------------------------------------------------------------
# |"carat"  |"cut"      |"color"  |"clarity"  |"depth"  |"table"  |"price"  |"x"   |"y"   |"z"   |
# ------------------------------------------------------------------------------------------------
# |0.23     |Ideal      |E        |SI2        |61.5     |55.0     |326      |3.95  |3.98  |2.43  |
# |0.21     |Premium    |E        |SI1        |59.8     |61.0     |326      |3.89  |3.84  |2.31  |
# |0.23     |Good       |E        |VS1        |56.9     |65.0     |327      |4.05  |4.07  |2.31  |
# |0.29     |Premium    |I        |VS2        |62.4     |58.0     |334      |4.2   |4.23  |2.63  |
# |0.31     |Good       |J        |SI2        |63.3     |58.0     |335      |4.34  |4.35  |2.75  |
# |0.24     |Very Good  |J        |VVS2       |62.8     |57.0     |336      |3.94  |3.96  |2.48  |
# |0.24     |Very Good  |I        |VVS1       |62.3     |57.0     |336      |3.95  |3.98  |2.47  |
# |0.26     |Very Good  |H        |SI1        |61.9     |55.0     |337      |4.07  |4.11  |2.53  |
# |0.22     |Fair       |E        |VS2        |65.1     |61.0     |337      |3.87  |3.78  |2.49  |
# |0.23     |Very Good  |H        |VS1        |59.4     |61.0     |338      |4.0   |4.05  |2.39  |
# ------------------------------------------------------------------------------------------------

# %%
# Categorize all the features for modeling
CATEGORICAL_COLUMNS = ["CUT", "COLOR", "CLARITY"]
CATEGORICAL_COLUMNS_OE = ["CUT_OE", "COLOR_OE", "CLARITY_OE"] # To name the ordinal encoded columns
NUMERICAL_COLUMNS = ["CARAT", "DEPTH", "TABLE", "X", "Y", "Z"]

LABEL_COLUMNS = ['PRICE']
OUTPUT_COLUMNS = ['PREDICTED_PRICE']

# %%
diamonds_df.show()
# Out:
# ------------------------------------------------------------------------------------------------
# |"carat"  |"cut"      |"color"  |"clarity"  |"depth"  |"table"  |"price"  |"x"   |"y"   |"z"   |
# ------------------------------------------------------------------------------------------------
# |0.23     |Ideal      |E        |SI2        |61.5     |55.0     |326      |3.95  |3.98  |2.43  |
# |0.21     |Premium    |E        |SI1        |59.8     |61.0     |326      |3.89  |3.84  |2.31  |
# |0.23     |Good       |E        |VS1        |56.9     |65.0     |327      |4.05  |4.07  |2.31  |
# |0.29     |Premium    |I        |VS2        |62.4     |58.0     |334      |4.2   |4.23  |2.63  |
# |0.31     |Good       |J        |SI2        |63.3     |58.0     |335      |4.34  |4.35  |2.75  |
# |0.24     |Very Good  |J        |VVS2       |62.8     |57.0     |336      |3.94  |3.96  |2.48  |
# |0.24     |Very Good  |I        |VVS1       |62.3     |57.0     |336      |3.95  |3.98  |2.47  |
# |0.26     |Very Good  |H        |SI1        |61.9     |55.0     |337      |4.07  |4.11  |2.53  |
# |0.22     |Fair       |E        |VS2        |65.1     |61.0     |337      |3.87  |3.78  |2.49  |
# |0.23     |Very Good  |H        |VS1        |59.4     |61.0     |338      |4.0   |4.05  |2.39  |
# ------------------------------------------------------------------------------------------------

# %%
###PREPROCESSING
# Normalize the CARAT column
snowml_mms = snowml.MinMaxScaler(input_cols=["carat"], output_cols=["CARAT_NORM"])
normalized_diamonds_df = snowml_mms.fit(diamonds_df).transform(diamonds_df)

# Reduce the number of decimals
new_col = normalized_diamonds_df.col("CARAT_NORM").cast(DecimalType(7, 6))
normalized_diamonds_df = normalized_diamonds_df.with_column("CARAT_NORM", new_col)

normalized_diamonds_df.show()
# Out:
# ---------------------------------------------------------------------------
# SnowparkSQLException                      Traceback (most recent call last)
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/utils/parallelize.py:63, in map_dataframe_by_column(df, cols, map_func, partition_size, statement_params)
#      62 try:
# ---> 63     n_partitions = math.ceil(len(df[cols].columns) / partition_size)
#      64 except Exception:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/dataframe.py:1056, in DataFrame.columns(self)
#    1042 """Returns all column names as a list.
#    1043
#    1044 The returned column names are consistent with the Snowflake database object `identifier syntax <https://docs.snowflake.com/en/sql-reference/identifiers-syntax.html>`_.
#    (...)
#    1054 ==================================   ==========================
#    1055 """
# -> 1056 return self.schema.names
#
# File /opt/conda/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/dataframe.py:4102, in DataFrame.schema(self)
#    4099 """The definition of the columns in this DataFrame (the "relational schema" for
#    4100 the DataFrame).
#    4101 """
# -> 4102 return StructType._from_attributes(self._plan.attributes)
#
# File /opt/conda/lib/python3.9/functools.py:993, in cached_property.__get__(self, instance, owner)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:319, in SnowflakePlan.attributes(self)
#     317 @cached_property
#     318 def attributes(self) -> List[Attribute]:
# --> 319     output = analyze_attributes(self.schema_query, self.session)
#     320     # No simplifier case relies on this schema_query change to update SHOW TABLES to a nested sql friendly query.
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/analyzer/schema_utils.py:91, in analyze_attributes(sql, session)
#      89     return convert_result_meta_to_attribute(session._conn._cursor.description)
# ---> 91 return session._get_result_attributes(sql)
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/session.py:2104, in Session._get_result_attributes(self, query)
#    2103 def _get_result_attributes(self, query: str) -> List[Attribute]:
# -> 2104     return self._conn.get_result_attributes(query)
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:186, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     183         ne = SnowparkClientExceptionMessages.SQL_EXCEPTION_FROM_PROGRAMMING_ERROR(
#     184             e
#     185         )
# --> 186         raise ne.with_traceback(tb) from None
#     187 else:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/analyzer/snowflake_plan.py:122, in SnowflakePlan.Decorator.wrap_exception.<locals>.wrap(*args, **kwargs)
#     121 try:
# --> 122     return func(*args, **kwargs)
#     123 except snowflake.connector.errors.ProgrammingError as e:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/server_connection.py:233, in ServerConnection.get_result_attributes(self, query)
#     231 @SnowflakePlan.Decorator.wrap_exception
#     232 def get_result_attributes(self, query: str) -> List[Attribute]:
# --> 233     return convert_result_meta_to_attribute(run_new_describe(self._cursor, query))
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/snowpark/_internal/analyzer/schema_utils.py:144, in run_new_describe(cursor, query)
#     142 if hasattr(cursor, "_describe_internal"):
#     143     # Pyright does not perform narrowing here
# --> 144     return cursor._describe_internal(query)  # pyright: ignore
#     145 else:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/connector/cursor.py:1120, in SnowflakeCursor._describe_internal(self, *args, **kwargs)
#    1119 kwargs["_describe_only"] = kwargs["_is_internal"] = True
# -> 1120 self.execute(*args, **kwargs)
#    1121 return self._description
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/connector/cursor.py:1080, in SnowflakeCursor.execute(self, command, params, _bind_stage, timeout, _exec_async, _no_retry, _do_reset, _put_callback, _put_azure_callback, _put_callback_output_stream, _get_callback, _get_azure_callback, _get_callback_output_stream, _show_progress_bar, _statement_params, _is_internal, _describe_only, _no_results, _is_put_get, _raise_put_get_error, _force_put_overwrite, _skip_upload_on_content_match, file_stream, num_statements)
#    1079     error_class = IntegrityError if is_integrity_error else ProgrammingError
# -> 1080     Error.errorhandler_wrapper(self.connection, self, error_class, errvalue)
#    1081 return self
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/connector/errors.py:290, in Error.errorhandler_wrapper(connection, cursor, error_class, error_value)
#     274 """Error handler wrapper that calls the errorhandler method.
#     275
#     276 Args:
#    (...)
#     287     exception to the first handler in that order.
#     288 """
# --> 290 handed_over = Error.hand_to_other_handler(
#     291     connection,
#     292     cursor,
#     293     error_class,
#     294     error_value,
#     295 )
#     296 if not handed_over:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/connector/errors.py:345, in Error.hand_to_other_handler(connection, cursor, error_class, error_value)
#     344 cursor.messages.append((error_class, error_value))
# --> 345 cursor.errorhandler(connection, cursor, error_class, error_value)
#     346 return True
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/connector/errors.py:221, in Error.default_errorhandler(connection, cursor, error_class, error_value)
#     220 done_format_msg = error_value.get("done_format_msg")
# --> 221 raise error_class(
#     222     msg=error_value.get("msg"),
#     223     errno=None if errno is None else int(errno),
#     224     sqlstate=error_value.get("sqlstate"),
#     225     sfqid=error_value.get("sfqid"),
#     226     query=error_value.get("query"),
#     227     done_format_msg=(
#     228         None if done_format_msg is None else bool(done_format_msg)
#     229     ),
#     230     connection=connection,
#     231     cursor=cursor,
#     232 )
#
# SnowparkSQLException: (1304): 01b49954-0000-6544-0000-576d06ad267e: 000904 (42000): SQL compilation error: error line 1 at position 7
# invalid identifier 'CARAT'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/telemetry.py:367, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     366 try:
# --> 367     res = func(*args, **kwargs)
#     368 except Exception as e:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/min_max_scaler.py:167, in MinMaxScaler.fit(self, dataset)
#     166 else:
# --> 167     self._fit_snowpark(dataset)
#     169 self._is_fitted = True
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/min_max_scaler.py:186, in MinMaxScaler._fit_snowpark(self, dataset)
#     185 self._check_input_column_types(dataset)
# --> 186 computed_states = self._compute(dataset, self.input_cols, self.custom_states)
#     188 # assign states to the object
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/framework/base.py:474, in BaseEstimator._compute(self, dataset, cols, states)
#     472     return res
# --> 474 _results = parallelize.map_dataframe_by_column(
#     475     df=dataset,
#     476     cols=cols,
#     477     map_func=_compute_on_partition,
#     478     partition_size=40,
#     479     statement_params=telemetry.get_statement_params(PROJECT, SUBPROJECT, self.__class__.__name__),
#     480 )
#     482 computed_dict: Dict[str, Dict[str, Union[int, float, str]]] = {}
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/utils/parallelize.py:65, in map_dataframe_by_column(df, cols, map_func, partition_size, statement_params)
#      64 except Exception:
# ---> 65     raise Exception(f"Provided column names {cols} does not index into the dataset.")
#      67 # This should never happen
#
# Exception: Provided column names ['carat'] does not index into the dataset.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[21], line 4
#       1 ###PREPROCESSING
#       2 # Normalize the CARAT column
#       3 snowml_mms = snowml.MinMaxScaler(input_cols=["carat"], output_cols=["CARAT_NORM"])
# ----> 4 normalized_diamonds_df = snowml_mms.fit(diamonds_df).transform(diamonds_df)
#       6 # Reduce the number of decimals
#       7 new_col = normalized_diamonds_df.col("CARAT_NORM").cast(DecimalType(7, 6))
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/telemetry.py:389, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     387         raise me.original_exception from None
#     388     else:
# --> 389         raise me.original_exception from e
#     390 else:
#     391     return update_stmt_params_if_snowpark_df(res, statement_params)
#
# Exception: (0000) Provided column names ['carat'] does not index into the dataset.
