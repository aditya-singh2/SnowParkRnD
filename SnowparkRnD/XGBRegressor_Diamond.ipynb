# %%
# Snowpark for Python
from snowflake.snowpark import Session
from snowflake.snowpark.version import VERSION
from snowflake.snowpark.functions import udf
import snowflake.snowpark.functions as F

# Snowpark ML
from snowflake.ml.modeling.xgboost import XGBRegressor
from snowflake.ml.modeling.model_selection import GridSearchCV
from snowflake.ml.registry import Registry
from snowflake.ml._internal.utils import identifier
import snowflake.ml.modeling.preprocessing as snowml
from snowflake.snowpark.types import DecimalType

import pandas as pd
import numpy as np

# %%
connection_parameters = {
    "account": "ug94937.us-east4.gcp",
    "user": "ADITYASINGH",
    "password": os.environ.get('SF_Password'),
    "role": "ADITYASINGH",  # optional
    "warehouse": "FOSFOR_INSIGHT_WH",  # optional
#     "authenticator": "externalbrowser", # optional
    "database": "FIRST_DB",  # optional
    "schema": "PUBLIC",  # optional
}

# %%
# Make a Snowpark Connection

################################################################################################################
#  You can also use the SnowSQL Client to configure your connection params:
#  https://docs.snowflake.com/en/user-guide/snowsql-install-config.html
#
#  >>> from snowflake.ml.utils import connection_params
#  >>> session = Session.builder.configs(connection_params.SnowflakeLoginOptions()
#  >>> ).create()   
#
#  NOTE: If you have named connection params then specify the connection name
#  Example:
#  
#  >>> session = Session.builder.configs(
#  >>> connection_params.SnowflakeLoginOptions(connection_name='connections.snowml')
#  >>> ).create()
#
#################################################################################################################

# Edit the connection.json before creating the session object below
# Create Snowflake Session object
# connection_parameters = json.load(open('connection.json'))
session = Session.builder.configs(connection_parameters).create()
session.sql_simplifier_enabled = True

snowflake_environment = session.sql('SELECT current_user(), current_version()').collect()
snowpark_version = VERSION

# Current Environment Details
print('\nConnection Established with the following parameters:')
print('User                        : {}'.format(snowflake_environment[0][0]))
print('Role                        : {}'.format(session.get_current_role()))
print('Database                    : {}'.format(session.get_current_database()))
print('Schema                      : {}'.format(session.get_current_schema()))
print('Warehouse                   : {}'.format(session.get_current_warehouse()))
print('Snowflake version           : {}'.format(snowflake_environment[0][1]))
print('Snowpark for Python version : {}.{}.{}'.format(snowpark_version[0],snowpark_version[1],snowpark_version[2]))
# Out:
# Connection Established with the following parameters:
# User                        : ADITYASINGH
# Role                        : "ADITYASINGH"
# Database                    : "FIRST_DB"
# Schema                      : "PUBLIC"
# Warehouse                   : "FOSFOR_INSIGHT_WH"
# Snowflake version           : 8.20.10
# Snowpark for Python version : 1.17.0

# %%
data = pd.read_csv('/data/diamonds.csv')
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data=data.drop("Unnamed: 0" , axis =1)
data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
data.columns = map(str.upper, data.columns)
data.head()
# Out:
#    CARAT      CUT COLOR CLARITY  DEPTH  TABLE  PRICE     X     Y     Z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#moving data to snowflake df
diamonds_df = session.create_dataframe(data)
diamonds_df.show()
# Out:
# ------------------------------------------------------------------------------------------------
# |"CARAT"  |"CUT"      |"COLOR"  |"CLARITY"  |"DEPTH"  |"TABLE"  |"PRICE"  |"X"   |"Y"   |"Z"   |
# ------------------------------------------------------------------------------------------------
# |0.23     |Ideal      |E        |SI2        |61.5     |55.0     |326      |3.95  |3.98  |2.43  |
# |0.21     |Premium    |E        |SI1        |59.8     |61.0     |326      |3.89  |3.84  |2.31  |
# |0.23     |Good       |E        |VS1        |56.9     |65.0     |327      |4.05  |4.07  |2.31  |
# |0.29     |Premium    |I        |VS2        |62.4     |58.0     |334      |4.2   |4.23  |2.63  |
# |0.31     |Good       |J        |SI2        |63.3     |58.0     |335      |4.34  |4.35  |2.75  |
# |0.24     |Very Good  |J        |VVS2       |62.8     |57.0     |336      |3.94  |3.96  |2.48  |
# |0.24     |Very Good  |I        |VVS1       |62.3     |57.0     |336      |3.95  |3.98  |2.47  |
# |0.26     |Very Good  |H        |SI1        |61.9     |55.0     |337      |4.07  |4.11  |2.53  |
# |0.22     |Fair       |E        |VS2        |65.1     |61.0     |337      |3.87  |3.78  |2.49  |
# |0.23     |Very Good  |H        |VS1        |59.4     |61.0     |338      |4.0   |4.05  |2.39  |
# ------------------------------------------------------------------------------------------------

# %%
# Categorize all the features for modeling
CATEGORICAL_COLUMNS = ["CUT", "COLOR", "CLARITY"]
CATEGORICAL_COLUMNS_OE = ["CUT_OE", "COLOR_OE", "CLARITY_OE"] # To name the ordinal encoded columns
NUMERICAL_COLUMNS = ["CARAT", "DEPTH", "TABLE", "X", "Y", "Z"]

LABEL_COLUMNS = ['PRICE']
OUTPUT_COLUMNS = ['PREDICTED_PRICE']

# %%
diamonds_df.show()
# Out:
# ------------------------------------------------------------------------------------------------
# |"CARAT"  |"CUT"      |"COLOR"  |"CLARITY"  |"DEPTH"  |"TABLE"  |"PRICE"  |"X"   |"Y"   |"Z"   |
# ------------------------------------------------------------------------------------------------
# |0.23     |Ideal      |E        |SI2        |61.5     |55.0     |326      |3.95  |3.98  |2.43  |
# |0.21     |Premium    |E        |SI1        |59.8     |61.0     |326      |3.89  |3.84  |2.31  |
# |0.23     |Good       |E        |VS1        |56.9     |65.0     |327      |4.05  |4.07  |2.31  |
# |0.29     |Premium    |I        |VS2        |62.4     |58.0     |334      |4.2   |4.23  |2.63  |
# |0.31     |Good       |J        |SI2        |63.3     |58.0     |335      |4.34  |4.35  |2.75  |
# |0.24     |Very Good  |J        |VVS2       |62.8     |57.0     |336      |3.94  |3.96  |2.48  |
# |0.24     |Very Good  |I        |VVS1       |62.3     |57.0     |336      |3.95  |3.98  |2.47  |
# |0.26     |Very Good  |H        |SI1        |61.9     |55.0     |337      |4.07  |4.11  |2.53  |
# |0.22     |Fair       |E        |VS2        |65.1     |61.0     |337      |3.87  |3.78  |2.49  |
# |0.23     |Very Good  |H        |VS1        |59.4     |61.0     |338      |4.0   |4.05  |2.39  |
# ------------------------------------------------------------------------------------------------

# %%
###PREPROCESSING
# Normalize the CARAT column
snowml_mms = snowml.MinMaxScaler(input_cols=["carat"], output_cols=["CARAT_NORM"])
normalized_diamonds_df = snowml_mms.fit(diamonds_df).transform(diamonds_df)

# Reduce the number of decimals
new_col = normalized_diamonds_df.col("CARAT_NORM").cast(DecimalType(7, 6))
normalized_diamonds_df = normalized_diamonds_df.with_column("CARAT_NORM", new_col)

normalized_diamonds_df.show()
# Out:
# ---------------------------------------------------------------------------------------------------------------
# |"CARAT"  |"CUT"      |"COLOR"  |"CLARITY"  |"DEPTH"  |"TABLE"  |"PRICE"  |"X"   |"Y"   |"Z"   |"CARAT_NORM"  |
# ---------------------------------------------------------------------------------------------------------------
# |0.23     |Ideal      |E        |SI2        |61.5     |55.0     |326      |3.95  |3.98  |2.43  |0.006237      |
# |0.21     |Premium    |E        |SI1        |59.8     |61.0     |326      |3.89  |3.84  |2.31  |0.002079      |
# |0.23     |Good       |E        |VS1        |56.9     |65.0     |327      |4.05  |4.07  |2.31  |0.006237      |
# |0.29     |Premium    |I        |VS2        |62.4     |58.0     |334      |4.2   |4.23  |2.63  |0.018711      |
# |0.31     |Good       |J        |SI2        |63.3     |58.0     |335      |4.34  |4.35  |2.75  |0.022869      |
# |0.24     |Very Good  |J        |VVS2       |62.8     |57.0     |336      |3.94  |3.96  |2.48  |0.008316      |
# |0.24     |Very Good  |I        |VVS1       |62.3     |57.0     |336      |3.95  |3.98  |2.47  |0.008316      |
# |0.26     |Very Good  |H        |SI1        |61.9     |55.0     |337      |4.07  |4.11  |2.53  |0.012474      |
# |0.22     |Fair       |E        |VS2        |65.1     |61.0     |337      |3.87  |3.78  |2.49  |0.004158      |
# |0.23     |Very Good  |H        |VS1        |59.4     |61.0     |338      |4.0   |4.05  |2.39  |0.006237      |
# ---------------------------------------------------------------------------------------------------------------

# %%
# Encode CUT and CLARITY preserve ordinal importance
categories = {
    "CUT": np.array(["IDEAL", "PREMIUM", "VERY_GOOD", "GOOD", "FAIR"]),
    "CLARITY": np.array(["IF", "VVS1", "VVS2", "VS1", "VS2", "SI1", "SI2", "I1", "I2", "I3"]),
}
snowml_oe = snowml.OrdinalEncoder(input_cols=["CUT", "CLARITY"], output_cols=["CUT_OE", "CLARITY_OE"], categories=categories)
ord_encoded_diamonds_df = snowml_oe.fit(normalized_diamonds_df).transform(normalized_diamonds_df)

# Show the encoding
print(snowml_oe._state_pandas)

ord_encoded_diamonds_df.show()
# Out:
# ---------------------------------------------------------------------------
# SnowflakeMLException                      Traceback (most recent call last)
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/telemetry.py:367, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     366 try:
# --> 367     res = func(*args, **kwargs)
#     368 except Exception as e:
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/ordinal_encoder.py:201, in OrdinalEncoder.fit(self, dataset)
#     200 else:
# --> 201     self._fit_snowpark(dataset)
#     202 self._validate_unknown_value()
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/ordinal_encoder.py:241, in OrdinalEncoder._fit_snowpark(self, dataset)
#     240 def _fit_snowpark(self, dataset: snowpark.DataFrame) -> None:
# --> 241     self._fit_category_state(dataset)
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/ordinal_encoder.py:252, in OrdinalEncoder._fit_category_state(self, dataset)
#     251 # columns: COLUMN_NAME, CATEGORY, INDEX
# --> 252 state_df = self._get_category_index_state_df(dataset)
#     253 # save the dataframe on server side so that transform doesn't need to upload
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/modeling/preprocessing/ordinal_encoder.py:345, in OrdinalEncoder._get_category_index_state_df(self, dataset)
#     344         msg = f"Found unknown categories during fit:\n{unknown_pandas.to_string()}"
# --> 345         raise exceptions.SnowflakeMLException(
#     346             error_code=error_codes.INVALID_DATA,
#     347             original_exception=ValueError(msg),
#     348         )
#     350 return given_state_df
#
# SnowflakeMLException: ValueError('(2112) Found unknown categories during fit:\n  COLUMN_NAME UNKNOWN_VALUE\n0         CUT          Fair\n1         CUT     Very Good\n2         CUT         Ideal\n3         CUT          Good\n4         CUT       Premium')
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 7
#       2 categories = {
#       3     "CUT": np.array(["IDEAL", "PREMIUM", "VERY_GOOD", "GOOD", "FAIR"]),
#       4     "CLARITY": np.array(["IF", "VVS1", "VVS2", "VS1", "VS2", "SI1", "SI2", "I1", "I2", "I3"]),
#       5 }
#       6 snowml_oe = snowml.OrdinalEncoder(input_cols=["CUT", "CLARITY"], output_cols=["CUT_OE", "CLARITY_OE"], categories=categories)
# ----> 7 ord_encoded_diamonds_df = snowml_oe.fit(normalized_diamonds_df).transform(normalized_diamonds_df)
#       9 # Show the encoding
#      10 print(snowml_oe._state_pandas)
#
# File /packages/Python-3.9-Snowpark/c4ae710c-7618-477a-97d0-5337fbf62a9a/3.9/snowflake/ml/_internal/telemetry.py:389, in send_api_usage_telemetry.<locals>.decorator.<locals>.wrap(*args, **kwargs)
#     387         raise me.original_exception from None
#     388     else:
# --> 389         raise me.original_exception from e
#     390 else:
#     391     return update_stmt_params_if_snowpark_df(res, statement_params)
#
# ValueError: (2112) Found unknown categories during fit:
#   COLUMN_NAME UNKNOWN_VALUE
# 0         CUT          Fair
# 1         CUT     Very Good
# 2         CUT         Ideal
# 3         CUT          Good
# 4         CUT       Premium
